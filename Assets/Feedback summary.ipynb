# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 108 like multiplayer
# 7 like collect coins
# 7 like maze design
# 6 like color design
# 10+ none

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'multiplayer', 'collect coins', 'maze design', 'color design', 'none'
sizes = [108, 7, 7, 6, 10]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title("What were the most enjoyable aspect(s) of the game?")
plt.show()

# %% [markdown]
# Too difficult 10+
#
# Unclear tutorial 12
# Why coins 5
#
# No single mode 10
#
# Weird camera 14
# Frame rate 8
#
# Game move speed 3
# No difference between two world 3
#
# Inertia 3

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Too difficult', 'Unclear tutorial', 'Why coins', 'No single mode', 'Weird camera', 'Frame rate', 'Game move speed', 'No difference between two world', 'Inertia'
sizes = [10, 12, 5, 10, 14, 8, 3, 3, 3]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title("Were there any unclear or frustrating parts?")
plt.show()
